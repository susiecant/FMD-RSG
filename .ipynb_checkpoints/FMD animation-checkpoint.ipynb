# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
from matplotlib import animation
from scipy.spatial import distance
import time
PATH = '../StudyGroup/'

# %% [markdown]
# # Takes raw data and converts into a pandas dataframe (all counties)

# %%
raw_data = pd.read_csv(PATH +'Farms_2010_RSG', sep = '\s+', header = None, names = ['County Number', 'Parish Number', 'Holding Number',
                                                                              'X coordinate', 'Y coordinate', 'Number of Cattle', 
                                                                              'Number of Sheep'])

# %% [markdown]
# # Consider just cumbria (county 8)

# %%
cumbria = raw_data[raw_data['County Number']==8]
cumbria = cumbria.reset_index(drop = True)
xcoord = cumbria['X coordinate']/100000
ycoord = cumbria['Y coordinate']/100000
cattle = cumbria['Number of Cattle']
sheep = cumbria['Number of Sheep']

# %% [markdown]
# # Calculate Euclidean Distance

# %%
joinedinput = np.column_stack((xcoord.values, ycoord.values)) 
dist = distance.cdist(joinedinput, joinedinput, 'euclidean')

# %%
# dist = np.zeros(shape =(len(cumbria), len(cumbria)))

# for indexi, i in cumbria.iterrows():
#     for indexj, j in cumbria.iterrows():
#         dist[indexi,indexj] = np.sqrt((i['X coordinate'] - j['X coordinate'])**2 + (i['Y coordinate'] - j['Y coordinate'])**2)

# %%
# dist

# %% [markdown]
# ### Infect a farm randomally.
# I is a vector of the farms infected. 1 == exposed, 2 == infectious, 3 == culled.
#
# A is a dataframe of farms infected with information about at what time they were infected. Output are the removed farms with their location and time of culling.
#
# InfectedFarms is a dataframe that contains the information of both A and output.

# %%
r = np.random.randint(len(cumbria))
N = len(cumbria)
# if want to infect multiple farms in first step then
# r = np.random.randint(len(cumbria), size = 10)

#Check we haven't picked a farm with no animals
while cumbria.iloc[r]['Number of Cattle'] == 0 and cumbria.iloc[r]['Number of Sheep'] == 0: 
    r = np.random.randint(len(cumbria))

# %%
cumbria.iloc[r]; # information on our chosen farm
I = np.zeros(len(cumbria))
I[r] =1

# %%
Latent = np.random.negative_binomial(50, 50/55, N) #Draw latent periods
Infectious = np.random.negative_binomial(30, 30/39, N) #Draw infectious periods
mycolumns = ['Farm Number', 'Status', 'Time of Infection', 'Time of Culling',
                                       'Latent Period', 'Infectious Period', 'X coordinate', 'Y coordinate']
t = 0
InfectedFarms  = pd.DataFrame(columns =mycolumns)
A = np.zeros(shape=(len(cumbria),4))

output = np.zeros(shape=(len(cumbria),6))

# %%
A[0, :] = [r, 0, Latent[r], Infectious[r]] #farm (r), time since start (0), Latent, infecious period
InfectedFarms['Farm Number']= cumbria.index                                                                                               
InfectedFarms['Status' ] = np.zeros(N)
InfectedFarms['Latent Period'] = Latent
InfectedFarms['Infectious Period'] = Infectious
InfectedFarms['X coordinate'] = xcoord
InfectedFarms['Y coordinate'] = ycoord
InfectedFarms[['Time of Infection', 'Time of Culling']]=[-100,-100]
# [cumbria.index, np.zeros(N), Latent, Infectious, xcoord.values, ycoord.values]
# InfectedFarms

# %%
InfectedFarms.loc[r,['Status', 'Time of Infection']] =[1,t]
InfectedFarms.loc[[r]]
# Out:
#       Farm Number  Status  Time of Infection  Time of Culling  Latent Period  \
# 1228         1228     1.0                  0             -100              4
#
#       Infectious Period  X coordinate  Y coordinate
# 1228                  8        3.0531        5.3465

# %% [markdown]
# ### parameters

# %%
psi = 0.00657
nu = 1.99*(10**(-7))
xi = 2.65
zeta = 1.80
chi = 0.403

# %% [markdown]
# ### Initally make a new dataframe of only susceptible farms (i.e remove r)

# %%
# Sus = cumbria.copy() #Make a new dataframe
# Sus = Sus.reset_index(drop = True) #as made from cumbria data
# Sus.drop(r, inplace = True)
#If had more farms infected then:
# Sus.drop([r], inplace = True)

# %% [markdown]
# ### Visualise which farm we have infected

# %%
plt.plot(xcoord, ycoord, 'o',label = 'Susceptible')
plt.plot(xcoord[r], ycoord[r], 'o', label = 'Infected')
plt.legend(loc = 'upper right')

# %% [markdown]
# # Different Distance Kernels

# %%
def distancekernel1(x_sus, y_sus, x_inf, y_inf, phi):
    '''Cauchy distance kernel'''
    dij = (x_sus-x_inf)**2 + (y_sus - y_inf)**2
    return phi/(phi**2 + dij)

def distancekernel2(x_sus, y_sus, x_inf, y_inf, phi, rho): 
    '''Exponential distance kernel'''
    dij = np.sqrt((x_sus-x_inf)**2 + (y_sus - y_inf)**2)
    return exp(-np.sqrt(dij/phi)) + rho

def distancekernel3(x_sus, y_sus, x_inf, y_inf): 
    '''One from Matts code'''
    param = [-9.2123e-5, 9.5628e-4, 3.3966e-3, -3.3687e-2, -1.30519e-1, -0.609262, -3.231772]
    dij = ((x_sus-x_inf)**2 + (y_sus - y_inf)**2)/(1000**2)
    poly = np.zeros(7)
    for i in range(7):
        poly[i] = (dij**(6-i))*(param[i])
    return np.exp(sum(poly))
# phi = 0.1
Cauchy_dist = psi/(psi**2 + dist**2)
# Cauchy_dist[np.where(dist > 20000)] = 0
# Cauchy_dist

# %%
Cauchy_dist
# Out:
# array([[1.52207002e+02, 3.20334357e+01, 2.87332570e+01, ...,
#         1.34505598e-02, 1.67523954e-02, 1.35500317e-02],
#        [3.20334357e+01, 1.52207002e+02, 3.27991286e+01, ...,
#         1.36189988e-02, 1.70190587e-02, 1.37332513e-02],
#        [2.87332570e+01, 3.27991286e+01, 1.52207002e+02, ...,
#         1.39762287e-02, 1.74934478e-02, 1.40848710e-02],
#        ...,
#        [1.34505598e-02, 1.36189988e-02, 1.39762287e-02, ...,
#         1.52207002e+02, 1.01973312e+00, 1.59699405e+01],
#        [1.67523954e-02, 1.70190587e-02, 1.74934478e-02, ...,
#         1.01973312e+00, 1.52207002e+02, 1.26520962e+00],
#        [1.35500317e-02, 1.37332513e-02, 1.40848710e-02, ...,
#         1.59699405e+01, 1.26520962e+00, 1.52207002e+02]])

# %%
beta1 = np.zeros(N)
beta1 = nu*(xi*(cattle)**chi + (sheep)**chi)

# %% [markdown]
# # Parameters

# %%
# sum(dist>20000)
# # parameters
# S_cow = 10.5
# S_sheep =1 
# β_cow = 7.7e-7
# β_sheep =5.1e-7

# %%
# S_trans = np.zeros(len(cumbria))
# S_trans = cumbria['Number of Cattle']*S_cow + cumbria['Number of Sheep']*S_sheep

# S_trans

# %% [markdown]
# # Rate of infection
# $$ \lambda_i =  \sum_{j \in \text{infectious}} T  N_j K(d_{ij})$$

# %%
# def rateinfection(sus_farm, InfectedMatrix, kernel):
#     '''Input takes ONE susceptible farm and ALL infectious farms.
#     T is an array where each entry is the transmission from an infectious farm
#     D is an array where each entry is the distance kernel K(d) from an infectious farm to the susceptible farm'''
#     T = []
#     D = []
#     for k in range(len(InfectedMatrix.dropna(how = 'any'))):
#         T.append(np.array(InfectedMatrix.iloc[[k]]['Number of Cattle'])*β_cow + np.array(InfectedMatrix.iloc[[k]]['Number of Sheep'])*β_sheep)
#         D.append(kernel(np.array(sus_farm['X coordinate']), np.array(sus_farm['Y coordinate']), 
#                                  np.array(InfectedMatrix.loc[[k]]['X coordinate']), np.array(InfectedMatrix.loc[[k]]['Y coordinate'])))
#     return np.dot(np.transpose(T),D) # dot product is the sum

# %% [markdown]
# # Infectedfarms matrix

# %%
# Infectedfarms = pd.DataFrame(columns =['County Number', 'Parish Number', 
#                                        'Holding Number', 'X coordinate', 
#                                        'Y coordinate', 'Number of Cattle', 
#                                        'Number of Sheep', 'Status', 'Cull']) #Note added a column for status

# Infectedfarms = Infectedfarms.append(cumbria.iloc[[r]], ignore_index = True)
# Infectedfarms = Infectedfarms.fillna(1) #Makes Status set to 1

# %% [markdown]
# # Start infecting farms
#
# Probability a farm is infected is, $$ p_i = 1 - e^{-S N_i \sum_{j \in \text{infectious}} T N_j K(d_{ij})}$$.
#
# Then, from Matt's code sets probability to $ \frac{p_i}{1- (1-p_i)^{\text{ number farms infected}}}$

# %%
# InfectedFarms.loc[InfectedFarms['Time of Infection'] +
#                   InfectedFarms['Latent Period'] == -93,'Status'] = 3

# print(I ==3)
sum(I)
# cattle[InfectedFarms['Status']==1].index
# Out:
# 1.0

# %%
start_time = time.time()

while sum(InfectedFarms['Status'] == 1) + sum(InfectedFarms['Status'] == 2) > 0:
    In = InfectedFarms['Status']
#Calculate transmission rate

    t = t + 1
    print("Day", t, "Exposed", sum(I == 1), "Infected", sum(I == 2), "Culled", sum(I == 3))

    beta_ben = np.zeros(N)
    beta = np.zeros(N)
    for j in range(N):
        beta[j] = beta1[j]*(np.sum((zeta*(cattle[In == 2]**chi) + sheep[In == 2]**chi)*Cauchy_dist[In == 2, j]))   
        beta_ben[j] = beta1[j]*(np.sum((zeta*(cattle[I == 2]**chi) + sheep[I == 2]**chi)*Cauchy_dist[I == 2, j]))   
#Calculate probability of infection
    
    prob_inf = 1 - np.exp(-beta)
    prob_inf_ben = 1-np.exp(-beta_ben)
    print(prob_inf_ben)
    
#Infect if probability is less that a uniform sample

    unif = np.random.uniform(0, 1, N)

    for i in range(0,N):
        if (unif[i] <= prob_inf[i] and I[i] == 0):
            I[i] =  1
            InfectedFarms.loc[i, ['Status', 'Time of Infection']] = [1, t]
            su = sum(I != 0)
            A[su-1, ] = [i, t, s[i], r[i]]
            #print("Farm", i, "Day", t)
            
#Update states
    InfectedFarms.loc[InfectedFarms['Time of Infection'] + InfectedFarms['Latent Period'] == t,'Status'] = 2
    inf = A[:,0][A[:,1] + A[:,2] == t] #Move to I state once latent period is over
    I[inf.astype(np.int64)] = 2
    InfectedFarms.loc[InfectedFarms['Time of Infection'] + InfectedFarms['Latent Period'] 
                      + InfectedFarms['Infectious Period'] == t,'Status'] = 3
    InfectedFarms.loc[InfectedFarms['Status'] ==3, 'Time of Culling'] = t
    rem = A[:,0][A[:,1] + A[:,2] + A[:,3] == t] #Move to R state once infectious period is over
    I[rem.astype(np.int64)] = 3
    out = sum(output[:,1] != 0)
    
#Store output

    if len(rem) > 0:
        for i in range(0,len(rem)):
            output[out + i,] = [rem[i], t - A[i,2] - A[i,3], xcoord[rem.astype(np.int64)[i]], ycoord[rem.astype(np.int64)[i]], cattle[rem.astype(np.int64)[i]], sheep[rem.astype(np.int64)[i]]]
     
    
#     culledind = [i for i in range(np.size(I)) if I[i]==3]
#     infectind = [i for i in range(np.size(I)) if I[i]==2]
#     exposedind = [i for i in range(np.size(I)) if I[i]==1]
#     susceptind = [i for i in range(np.size(I)) if I[i]==0]
    
#     xculledplot = xinput[culledind]
#     yculledplot = yinput[culledind]
#     xinfectplot = xinput[infectind]
#     yinfectplot = yinput[infectind]
#     xexposedplot = xinput[exposedind]
#     yexposedplot = yinput[exposedind]
#     xsusceptplot = xinput[susceptind]
#     ysusceptplot = yinput[susceptind]
    
#     ax.clear()
#     ax.scatter(xsusceptplot, ysusceptplot, c='g', marker='o', s=6, label='Susceptible')
#     ax.scatter(xexposedplot, yexposedplot, c='b', marker='o', s=8, label='Exposed')
#     ax.scatter(xinfectplot, yinfectplot, c='k', marker='o', s=10, label='Infectious')
#     ax.scatter(xculledplot, yculledplot, c='r', marker='o', s=20, label='Culled')
#     ax.axis([0, sizex, 0, sizey])
#     ax.legend()
#     fig.canvas.draw()

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Day 1 Exposed 1 Infected 0 Culled 0
# [0. 0. 0. ... 0. 0. 0.]
# Day 2 Exposed 1 Infected 0 Culled 0
# [0. 0. 0. ... 0. 0. 0.]
# Day 3 Exposed 1 Infected 0 Culled 0
# [0. 0. 0. ... 0. 0. 0.]
# Day 4 Exposed 1 Infected 0 Culled 0
# [0. 0. 0. ... 0. 0. 0.]
# Day 5 Exposed 0 Infected 1 Culled 0
# [0.00000000e+00 0.00000000e+00 5.41469910e-06 ... 8.51214704e-08
#  7.41422621e-08 4.48732240e-08]
# Day 6 Exposed 0 Infected 1 Culled 0
# [0.00000000e+00 0.00000000e+00 5.41469910e-06 ... 8.51214704e-08
#  7.41422621e-08 4.48732240e-08]
# Day 7 Exposed 0 Infected 1 Culled 0
# [0.00000000e+00 0.00000000e+00 5.41469910e-06 ... 8.51214704e-08
#  7.41422621e-08 4.48732240e-08]
# Day 8 Exposed 0 Infected 1 Culled 0
# [0.00000000e+00 0.00000000e+00 5.41469910e-06 ... 8.51214704e-08
#  7.41422621e-08 4.48732240e-08]
# Day 9 Exposed 0 Infected 1 Culled 0
# [0.00000000e+00 0.00000000e+00 5.41469910e-06 ... 8.51214704e-08
#  7.41422621e-08 4.48732240e-08]
# Day 10 Exposed 0 Infected 1 Culled 0
# [0.00000000e+00 0.00000000e+00 5.41469910e-06 ... 8.51214704e-08
#  7.41422621e-08 4.48732240e-08]
# Day 11 Exposed 0 Infected 1 Culled 0
# [0.00000000e+00 0.00000000e+00 5.41469910e-06 ... 8.51214704e-08
#  7.41422621e-08 4.48732240e-08]
# Day 12 Exposed 0 Infected 1 Culled 0
# [0.00000000e+00 0.00000000e+00 5.41469910e-06 ... 8.51214704e-08
#  7.41422621e-08 4.48732240e-08]
# --- 101.32478380203247 seconds ---

# %%
InfectedFarms[InfectedFarms['Time of Infection']!=-100]
# Out:
#       Farm Number  Status  Time of Infection  Time of Culling  Latent Period  \
# 1412         1412     3.0                  0               13              5
#
#       Infectious Period  X coordinate  Y coordinate
# 1412                  8        3.5366        5.6283

# %%
t =0
while sum(I == 1) + sum(I == 2) > 0:

#Calculate transmission rate

    t = t + 1
    print("Day", t, "Exposed", sum(I == 1), "Infected", sum(I == 2), "Culled", sum(I == 3))

    beta = np.zeros(len(cumbria))

    for j in range(len(cumbria)):
        beta[j] = S_trans[j]*(np.sum(β_cow*(cattle[I == 2] + β_sheep*sheep[I == 2])*Cauchy_dist[I == 2, j]))       

#Calculate probability of infection
    
    prob_inf = 1 - np.exp(-beta)
    
#Infect if probability is less that a uniform sample

    unif = np.random.uniform(0, 1, len(cumbria))

    for i in range(0,len(cumbria)):
        if (unif[i] <= prob_inf[i] and I[i] == 0):
            I[i] =  1
            su = sum(I != 0)
            A[int(su-1), ] = [i, t, s[i], r[i]]
            print("Farm", i, "Day", t)
            
#Update states
        
    inf = A[:,0][A[:,1] + A[:,2] == t] #Move to I state once latent period is over (start time plus latent)
    I[inf.astype(np.int64)] = 2
    rem = A[:,0][A[:,1] + A[:,2] + A[:,3] == t] #Move to R state once infectious period is over
    I[rem.astype(np.int64)] = 3
    out = sum(output[:,1] != 0)
    
#Store output

    if len(rem) > 0:
        for i in range(0,len(rem)):
            output[out + i,] = [rem[i], t - A[i,2] - A[i,3], xcoord[rem.astype(np.int64)[i]], ycoord[rem.astype(np.int64)[i]], cattle[rem.astype(np.int64)[i]], sheep[rem.astype(np.int64)[i]]]
# Out:
# Day 1 Exposed 1 Infected 1 Culled 0
# Day 2 Exposed 1 Infected 1 Culled 0
# Day 3 Exposed 1 Infected 1 Culled 0
# Day 4 Exposed 1 Infected 1 Culled 0
# Day 5 Exposed 1 Infected 1 Culled 0
# Day 6 Exposed 1 Infected 1 Culled 0
# Day 7 Exposed 1 Infected 1 Culled 0
# Day 8 Exposed 1 Infected 1 Culled 0
# Day 9 Exposed 1 Infected 1 Culled 0
# Day 10 Exposed 1 Infected 1 Culled 0
# Day 11 Exposed 1 Infected 1 Culled 0
# Day 12 Exposed 1 Infected 1 Culled 0
# Day 13 Exposed 1 Infected 1 Culled 0
# Day 14 Exposed 1 Infected 0 Culled 1
# Day 15 Exposed 1 Infected 0 Culled 1
# Day 16 Exposed 1 Infected 0 Culled 1
# Day 17 Exposed 1 Infected 0 Culled 1
# Day 18 Exposed 1 Infected 0 Culled 1
# Day 19 Exposed 1 Infected 0 Culled 1
# Day 20 Exposed 1 Infected 0 Culled 1
# Day 21 Exposed 1 Infected 0 Culled 1
# Day 22 Exposed 1 Infected 0 Culled 1
# Day 23 Exposed 1 Infected 0 Culled 1
# Day 24 Exposed 1 Infected 0 Culled 1
# Day 25 Exposed 1 Infected 0 Culled 1
# Day 26 Exposed 1 Infected 0 Culled 1
# Day 27 Exposed 1 Infected 0 Culled 1
# Day 28 Exposed 1 Infected 0 Culled 1
# Day 29 Exposed 1 Infected 0 Culled 1
# Day 94 Exposed 1 Infected 0 Culled 1
# Day 95 Exposed 1 Infected 0 Culled 1
# Day 96 Exposed 1 Infected 0 Culled 1
# Day 97 Exposed 1 Infected 0 Culled 1
# Day 98 Exposed 1 Infected 0 Culled 1
# Day 99 Exposed 1 Infected 0 Culled 1
# Day 100 Exposed 1 Infected 0 Culled 1
# Day 101 Exposed 1 Infected 0 Culled 1
# Day 102 Exposed 1 Infected 0 Culled 1
# Day 103 Exposed 1 Infected 0 Culled 1
# Day 104 Exposed 1 Infected 0 Culled 1
# Day 105 Exposed 1 Infected 0 Culled 1
# Day 106 Exposed 1 Infected 0 Culled 1
# Day 107 Exposed 1 Infected 0 Culled 1
# Day 108 Exposed 1 Infected 0 Culled 1
# Day 109 Exposed 1 Infected 0 Culled 1
# Day 110 Exposed 1 Infected 0 Culled 1
# Day 111 Exposed 1 Infected 0 Culled 1
# Day 112 Exposed 1 Infected 0 Culled 1
# Day 113 Exposed 1 Infected 0 Culled 1
# Day 114 Exposed 1 Infected 0 Culled 1
# Day 115 Exposed 1 Infected 0 Culled 1
# Day 116 Exposed 1 Infected 0 Culled 1
# Day 117 Exposed 1 Infected 0 Culled 1
# Day 118 Exposed 1 Infected 0 Culled 1
# Day 119 Exposed 1 Infected 0 Culled 1
# Day 120 Exposed 1 Infected 0 Culled 1
# Day 121 Exposed 1 Infected 0 Culled 1
# Day 122 Exposed 1 Infected 0 Culled 1
# Day 123 Exposed 1 Infected 0 Culled 1
# Day 124 Exposed 1 Infected 0 Culled 1
# Day 125 Exposed 1 Infected 0 Culled 1
# Day 126 Exposed 1 Infected 0 Culled 1
# Day 127 Exposed 1 Infected 0 Culled 1
# Day 128 Exposed 1 Infected 0 Culled 1
# Day 129 Exposed 1 Infected 0 Culled 1
# Day 130 Exposed 1 Infected 0 Culled 1
# Day 131 Exposed 1 Infected 0 Culled 1
# Day 132 Exposed 1 Infected 0 Culled 1
# Day 133 Exposed 1 Infected 0 Culled 1
# Day 134 Exposed 1 Infected 0 Culled 1
# Day 135 Exposed 1 Infected 0 Culled 1
# Day 136 Exposed 1 Infected 0 Culled 1
# Day 137 Exposed 1 Infected 0 Culled 1
# Day 138 Exposed 1 Infected 0 Culled 1
# Day 139 Exposed 1 Infected 0 Culled 1
# Day 140 Exposed 1 Infected 0 Culled 1
# Day 141 Exposed 1 Infected 0 Culled 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-52d4046a3650> in <module>()
#      10
#      11     for j in range(len(cumbria)):
# ---> 12         beta[j] = S_trans[j]*(np.sum(β_cow*(cattle[I == 2] + β_sheep*sheep[I == 2])*Cauchy_dist[I == 2, j]))
#      13
#      14 #Calculate probability of infection
#
# ~/.local/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(left, right, name, na_op)
#     743             index=left.index,
#     744             name=name,
# --> 745             dtype=dtype,
#     746         )
#     747
#
# ~/.local/lib/python3.5/site-packages/pandas/core/ops.py in _construct_result(left, result, index, name, dtype)
#     651
#     652 def _construct_result(left, result, index, name, dtype):
# --> 653     return left._constructor(result, index=index, name=name, dtype=dtype)
#     654
#     655
#
# KeyboardInterrupt:

# %%
# Susceptibles = Sus.copy()

# time = 8
# for t in range(time):
#     prob_farm_inf = [] #prob farm is infected 
#     rates = [] 
#     for k in range(len(Susceptibles)): #Calculates this for each susceptible
#         sus_k = np.array(Susceptibles.iloc[[k]]['Number of Cattle']*β_cow +
#                          Susceptibles.iloc[[k]]['Number of Sheep']*β_sheep)[0] #SN
#         rate = sus_k*rateinfection(Susceptibles.iloc[[k]], Infectedfarms[Infectedfarms['Cull'] != 3],
#                                    distancekernel3)[0]
#         rates.append(rate)
#         prob = 1-np.exp(-rate)
#         prob_farm_inf.append(prob)
#     new_prob = []
#     Num_farm_inf = len(Infectedfarms[Infectedfarms['Cull'] != 3])+1
#     for i in prob_farm_inf:
#         if i == 0:
#             new_prob.append(0)
#         else:
#             new_prob.append(i/(1-(1-i)**2))
#     infected = []
#     for index, k in enumerate(new_prob):
#         P = random.uniform(0,1)
#         if P < k:
#             infected.append(index)
#     Infectedfarms = Infectedfarms.append(Sus.iloc[infected],  ignore_index=True)
#     Infectedfarms.loc[Infectedfarms['Cull'] != 3, 'Status'] +=1
#     Infectedfarms = Infectedfarms.fillna(1)
#     print(infected)
#     Susceptibles.drop(infected, inplace = True)
#     Susceptibles = Susceptibles.reset_index(drop =True)
#     for farm in range(len(Infectedfarms)):
#         if np.array(Infectedfarms.iloc[[farm]]['Cull']) ==2:
#             Infectedfarms['Cull'][[farm]] = 3 #farm now culled
#     for l in range(len(Infectedfarms[Infectedfarms['Cull'] != 3])):
#         if np.array(Infectedfarms[Infectedfarms['Cull'] != 3].iloc[[l]]['Status']) == 5:
#             Infectedfarms['Cull'][[l]] = 2
#             barn = Infectedfarms[Infectedfarms['Cull'] != 3].iloc[[l]]
#             for k in range(len(Susceptibles)):
#                 if ((np.array(Susceptibles.iloc[[k]]['X coordinate']) - np.array(barn['X coordinate']))**2+
#                     (np.array(Susceptibles.iloc[[k]]['Y coordinate'])-np.array(barn['Y coordinate']))**2 < (3000)**2):
#                     Susceptibles['Number of Cattle'][[k]] = 0
#                     Susceptibles['Number of Sheep'][[k]]==0
#             for j in range(len(Infectedfarms[Infectedfarms['Cull'] != 3])):
#                 farm2 = Infectedfarms[Infectedfarms['Cull'] != 3]
#                 if ((np.array(farm2.iloc[[j]]['X coordinate']) - np.array(barn['X coordinate']))**2+
#                     (np.array(farm2.iloc[[j]]['Y coordinate'])-np.array(barn['Y coordinate']))**2 <= (3000)**2):
#                     farm2['Cull'][[j]] = 2

# %%
Infectedfarms
# Out:
#      County Number  Cull  Holding Number  Number of Cattle  Number of Sheep  \
# 0              8.0   2.0           116.0            147.08           1445.0
# 1              8.0   3.0             3.0             47.83           1734.0
# 2              8.0   3.0            10.0            227.83           2100.0
# 3              8.0   3.0            26.0            124.58            599.0
# 4              8.0   3.0            52.0            141.67            427.0
# 5              8.0   3.0            22.0            135.75           1236.0
# 6              8.0   3.0            73.0              0.00             34.0
# 7              8.0   3.0            19.0              7.33             32.0
# 8              8.0   3.0             7.0              0.00            460.0
# 9              8.0   1.0            85.0              0.00            214.0
# 10             8.0   1.0            13.0              0.00            110.0
# 11             8.0   1.0            24.0            476.50           1308.0
# 12             8.0   1.0            26.0            124.58            599.0
# 13             8.0   1.0            36.0            173.92            317.0
# 14             8.0   1.0            52.0            141.67            427.0
# 15             8.0   1.0            72.0              0.83           1395.0
# 22           406.0     5.0      341050.0      513750.0
# 23           406.0     5.0      340130.0      515600.0
# 24           406.0     5.0      339990.0      515930.0
# 25           408.0     5.0      356142.0      515626.0
# 26           418.0     5.0      358130.0      514810.0
# 27           309.0     4.0      365800.0      514470.0
# 28           309.0     4.0      365590.0      514460.0
# 29           315.0     4.0      364990.0      513290.0
# ..             ...     ...           ...           ...
# 804          409.0     1.0      359500.0      519600.0
# 805          627.0     1.0      323130.0      472760.0
# 806          629.0     1.0      319180.0      471390.0
# 807          629.0     1.0      317957.0      468038.0
# 808          630.0     1.0      326850.0      486570.0
# 809          632.0     1.0      320060.0      489350.0
# 810          632.0     1.0      323850.0      497250.0
# 811          632.0     1.0      323450.0      492950.0
# 812          633.0     1.0      338150.0      480300.0
# 813          633.0     1.0      338930.0      479700.0
# 814          633.0     1.0      338920.0      481810.0
# 815          634.0     1.0      331350.0      484830.0
# 816          634.0     1.0      332010.0      486860.0
# 817          634.0     1.0      330470.0      485170.0
# 818          634.0     1.0      334200.0      488800.0
# 819          634.0     1.0      335940.0      486610.0
# 820          634.0     1.0      329480.0      489620.0
# 821          634.0     1.0      336489.0      487639.0
# 822          635.0     1.0      329630.0      482560.0
# 823          635.0     1.0      329023.0      481640.0
# 824          635.0     1.0      330150.0      482120.0
# 825          635.0     1.0      330220.0      481830.0
# 826          635.0     1.0      331380.0      485300.0
# 827          635.0     1.0      330830.0      482780.0
# 828          635.0     1.0      330630.0      481720.0
# 829          635.0     1.0      330183.0      479403.0
# 830          635.0     1.0      330690.0      480020.0
# 831          637.0     1.0      351094.0      483367.0
# 832          637.0     1.0      336830.0      480120.0
# 833          638.0     1.0      333020.0      483320.0
#
# [834 rows x 9 columns]

# %%
for l in range(len(Infectedfarms[Infectedfarms['Cull'] != 3])):
        if np.array(Infectedfarms[Infectedfarms['Cull'] != 3].iloc[[l]]['Status']) == 5:
            Infectedfarms['Cull'][[l]] = 2
            barn = Infectedfarms[Infectedfarms['Cull'] != 3].iloc[[l]]
            for k in range(len(Susceptibles)):
                if ((np.array(Susceptibles.iloc[[k]]['X coordinate']) - np.array(barn['X coordinate']))**2+
                    (np.array(Susceptibles.iloc[[k]]['Y coordinate'])-np.array(barn['Y coordinate']))**2 < (3000)**2):
                    Susceptibles['Number of Cattle'][[k]] = 0
                    Susceptibles['Number of Sheep'][[k]]==0
            for j in range(len(Infectedfarms[Infectedfarms['Cull'] != 3])):
                farm2 = Infectedfarms[Infectedfarms['Cull'] != 3]
                if ((np.array(farm2.iloc[[j]]['X coordinate']) - np.array(barn['X coordinate']))**2+
                    (np.array(farm2.iloc[[j]]['Y coordinate'])-np.array(barn['Y coordinate']))**2 <= (3000)**2):
                    farm2['Cull'][[j]] = 2

# %%
for farm in range(len(Infectedfarms)):
    if np.array(Infectedfarms.iloc[[farm]]['Cull']) ==2:
        Infectedfarms['Cull'][[farm]] = 3 #farm now culled
for l in range(len(Infectedfarms[Infectedfarms['Cull'] != 3])):
    if np.array(Infectedfarms[Infectedfarms['Cull'] != 3].iloc[[l]]['Status']) == 5:
        Infectedfarms['Cull'][[l]] = 2
        barn = Infectedfarms[Infectedfarms['Cull'] != 3].iloc[[l]]
        for k in range(len(Susceptibles)):
            if ((np.array(Susceptibles.iloc[[k]]['X coordinate']) - np.array(barn['X coordinate']))**2+
                (np.array(Susceptibles.iloc[[k]]['Y coordinate'])-np.array(barn['Y coordinate']))**2 < (3000)**2):
                Susceptibles['Number of Cattle'][[k]] = 0
                Susceptibles['Number of Sheep'][[k]]==0
        for j in range(len(Infectedfarms[Infectedfarms['Cull'] != 3])):
            farm2 = Infectedfarms[Infectedfarms['Cull'] != 3]
            if ((np.array(farm2.iloc[[j]]['X coordinate']) - np.array(barn['X coordinate']))**2+
                (np.array(farm2.iloc[[j]]['Y coordinate'])-np.array(barn['Y coordinate']))**2 <= (3000)**2):
                farm2['Cull'][[j]] = 2

# %%
Infectedfarms
# Out:
#      County Number  Cull  Holding Number  Number of Cattle  Number of Sheep  \
# 0              8.0   3.0           116.0            147.08           1445.0
# 1              8.0   1.0            85.0              0.00            214.0
# 2              8.0   1.0             3.0             47.83           1734.0
# 3              8.0   1.0            24.0            476.50           1308.0
# 4              8.0   1.0            32.0            130.08            626.0
# 5              8.0   1.0            52.0            141.67            427.0
# 6              8.0   1.0            69.0            173.42            699.0
# 7              8.0   1.0           145.0             50.67            644.0
# 8              8.0   1.0            22.0            135.75           1236.0
# 9              8.0   1.0            68.0             46.08           1570.0
# 10             8.0   1.0            32.0              0.00           1111.0
# 11             8.0   1.0            89.0              0.00            361.0
# 12             8.0   1.0             6.0            102.00           1558.0
# 13             8.0   1.0            10.0              0.00            319.0
# 14             8.0   1.0             8.0             85.25           3257.0
# 15             8.0   1.0            24.0            476.50           1308.0
# 16             8.0   1.0            26.0            124.58            599.0
# 17             8.0   1.0            32.0            130.08            626.0
# 18             8.0   1.0            43.0             50.42              0.0
# 19             8.0   1.0            48.0            163.42            371.0
# 20             8.0   1.0            49.0            110.67              2.0
# 21             8.0   1.0            51.0            187.42              0.0
# 22             8.0   1.0            62.0              0.00            265.0
# 23             8.0   1.0            67.0            180.17           1298.0
# 24             8.0   1.0            72.0              0.83           1395.0
# 25             8.0   1.0            73.0             61.50            366.0
# 26             8.0   1.0            74.0              0.00            141.0
# 27             8.0   1.0            76.0              0.00           6022.0
# 28             8.0   1.0             7.0            327.92              0.0
# 29             8.0   1.0             9.0            206.08            615.0
# ..             ...   ...             ...               ...              ...
# 268            8.0   1.0             2.0            305.00             83.0
# 269            8.0   1.0            15.0            184.33            556.0
# 270            8.0   1.0             6.0             25.08            100.0
# 271            8.0   1.0            12.0            255.08           1019.0
# 272            8.0   1.0            21.0            201.67              0.0
# 273            8.0   1.0             7.0            625.25           8478.0
# 274            8.0   1.0             9.0            179.50            526.0
# 275            8.0   1.0             4.0              7.33            245.0
# 276            8.0   1.0            10.0             51.42            757.0
# 277            8.0   1.0             7.0            327.92              0.0
# 278            8.0   1.0            10.0             89.00              0.0
# 279            8.0   1.0            15.0             96.17            575.0
# 280            8.0   1.0            29.0             14.33              0.0
# 281            8.0   1.0            34.0            165.50           1740.0
# 282            8.0   1.0             2.0              2.08              0.0
# 283            8.0   1.0             5.0             27.42            159.0
# 284            8.0   1.0             9.0            206.08            615.0
# 294          405.0     1.0      361410.0      504550.0
# 295          405.0     1.0      365990.0      504010.0
# 296          405.0     1.0      364820.0      505310.0
# 297          405.0     1.0      366490.0      505420.0
#
# [298 rows x 9 columns]

# %%
for s in range(len(Infectedfarms)):
#     print(Infectedfarms.iloc[[s]]['Cull'])
    if np.array(Infectedfarms.iloc[[s]]['Cull']) == 0:
        Infectedfarms['Cull'][[s]] = 1
#         print(Infectedfarms.iloc[[s]]['Cull'])

# %%
Infectedfarms

# %%
for k in range(len(Sus2)):
    if ((np.array(Sus2.iloc[[k]]['X coordinate']) - np.array(Infectedfarms.iloc[[0]]['X coordinate']))**2+(np.array(Sus2.iloc[[k]]['Y coordinate'])-
                                                                                                           np.array(Infectedfarms.iloc[[0]]['Y coordinate']))**2 <= (3000**2)):
#     if ((Sus2.iloc[[k]]['X coordinate'] - Infectedfarms.iloc[[0]]['X coordinate'])**2+(Sus2.iloc[[k]]['Y coordinate']-Infectedfarms.iloc[[0]]['Y coordinate'])**2 <= (3000)**2):
        print(Sus2.iloc[[k]])

# %% [markdown]
# # Make an animation. This requires the dataframe Infectedfarms

# %%
Num_cases = []
Num_sheep = []
Num_cows = []
for i in (Infectedfarms['Status'].unique()):
    Num_cases.append(len(Infectedfarms[Infectedfarms['Status'] >= i]))
    Num_sheep.append(sum(Infectedfarms[Infectedfarms['Status']>=i]['Number of Sheep']))
    Num_cows.append(sum(Infectedfarms[Infectedfarms['Status']>=i]['Number of Cattle']))
plt.figure(figsize = (10,10))
plt.subplot(1,3,1)
plt.plot(range(5), Num_cases, label = 'Total number of cases')
plt.subplot(1,3,2)
plt.plot(range(5), Num_sheep, label = 'Total number of sheep')
plt.subplot(1,3,3)
plt.plot(range(5), Num_cows, label = 'Total number of cattle')
plt.legend(loc = 'upper left')
plt.title('Infectious over 5 timesteps')
plt.xlabel('Time step')

# %%
# make a global variable to store dataframes
global mylist
mylist = []
#so will display all infected farms from all days. Adapt this line (to do latent period etc)
for i in (Infectedfarms['Status'].unique()):
    mylist.append(Infectedfarms[Infectedfarms['Status'] >= i])


# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
# All suscpetible farms initally
ax = plt.axes(xlim=(min(cumbria['X coordinate']), max(cumbria['X coordinate'])), 
              ylim=(min(cumbria['Y coordinate']), max(cumbria['Y coordinate'])))
ax.plot(cumbria['X coordinate'], cumbria['Y coordinate'], 'o', alpha=.01, ms=10, label = 'Suscpetible farms')
#Fills line and text 
line, = ax.plot([], [], 'o', color = 'b', alpha = 0.3, label = 'Infected farms')
time_text = ax.text(0.57, 0.2, '', transform=ax.transAxes)
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    time_text.set_text('')
    return line,

# animation function of dataframes' list
def animate(i):
    line.set_data(mylist[i]['X coordinate'], mylist[i]['Y coordinate'])
    time_text.set_text('Infected farms at timestep {}'.format(i+1))
    return line, time_text

# call the animator, frames*(1/fps) is the speed of the animation.
# set number of frames to the length of your list of dataframes
anim = animation.FuncAnimation(fig, animate, frames=len(mylist), init_func=init, interval=20, blit=True)
plt.legend(loc = 'lower right')
plt.title('Cumbria')
plt.xlabel('X coordinate (m)')
plt.ylabel('Y coordiante (m)')
anim.save('basic_animation.mp4', fps=0.8)

# %%
0.001/(1-(1-0.001)**1000)
