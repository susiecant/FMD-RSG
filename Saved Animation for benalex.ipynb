# %%
import numpy as np
import random as random
import matplotlib.pyplot as plt
import time
import pandas as pd
import multiprocessing
import itertools
from scipy.spatial import distance
from matplotlib import animation

PATH = '../StudyGroup/'

# %% [markdown]
# # Alex's work
#
# Changed it all to pandas (removed A and I for one DataFrame called InfectedFarms) as I work better with a table, ignore if you prefer matrices

# %%
#Import Data
farmData = pd.read_csv(PATH +'Farms_2010_RSG', sep = '\s+', header = None, names = ['County Number', 'Parish Number', 'Holding Number',
                                                                              'X Coordinate', 'Y Coordinate', 'Number of Cattle', 
                                                                              'Number of Sheep'])
cumbData = farmData[farmData['County Number'] == 8]
cumbData = cumbData.reset_index(drop=True)
xCumb = cumbData['X Coordinate']/100000
yCumb = cumbData['Y Coordinate']/100000
xmax = np.max(xCumb)
xmin = np.min(xCumb)
ymax = np.max(yCumb)
ymin = np.min(yCumb)
sizex = xmax-xmin
sizey = ymax-ymin
cattleFrame = cumbData['Number of Cattle']
sheepFrame = cumbData['Number of Sheep']
xcoord = xCumb - xmin #Shift to start from (0, 0)
ycoord = yCumb - ymin #Shift to start from (0, 0)
N=np.size(xcoord)

# %%
#Calculate Euclidean distances
xinput = xcoord.values
yinput = ycoord.values
joinedinput = np.column_stack((xinput, yinput))
dist = distance.cdist(joinedinput, joinedinput, 'euclidean')

# %%
#Parameter values
        
psi = 0.00657
nu = 1.99*(10**(-7))
xi = 2.65
zeta = 1.80
chi = 0.403
s = np.random.negative_binomial(50, 50/55, N) #Draw latent periods
r = np.random.negative_binomial(30, 30/39, N) #Draw infectious periods

t = 0
A = np.zeros(shape=(N,4))
output = np.zeros(shape=(N,6))
mycolumns = ['Farm Number', 'Status', 'Time of Exposure', 'Time of Culling',
                                       'Latent Period', 'Infectious Period', 'X coordinate', 'Y coordinate']
InfectedFarms  = pd.DataFrame(columns =mycolumns)

# %%
np.mean(r)
# Out:
# 8.982488479262672

# %%
InfectedFarms['Farm Number']= cumbData.index                                                                                               
InfectedFarms['Status' ] = np.zeros(N)
InfectedFarms['Latent Period'] = s
InfectedFarms['Infectious Period'] = r
InfectedFarms['X coordinate'] = xinput
InfectedFarms['Y coordinate'] = yinput
InfectedFarms[['Time of Exposure', 'Time of Culling']]=[-100,-100]

# %%
#Calculate distance kernel
cattle = abs(cattleFrame.values)
sheep = abs(sheepFrame.values)
K = psi/(psi**2 + dist**2)

K[np.where(dist > 0.2)] = 0

beta1 = np.zeros(N)
beta1 = nu*(xi*(cattle)**chi + (sheep)**chi)

# %%
#Choose initial case

initial1 = random.randint(0,N)
initial2=initial1+1
initial3=initial2+1
initial4=initial3+1

# %%
InfectedFarms.loc[initial1,['Status', 'Time of Exposure']] =[1,t]
InfectedFarms.loc[initial2,['Status', 'Time of Exposure']] =[1,t]
InfectedFarms.loc[initial3,['Status', 'Time of Exposure']] =[1,t]
InfectedFarms.loc[initial4,['Status', 'Time of Exposure']] =[1,t]

# %%
plt.plot(InfectedFarms['X coordinate'], InfectedFarms['Y coordinate'], 'o',label = 'Susceptible')
plt.plot(InfectedFarms[InfectedFarms['Status']==1]['X coordinate'], InfectedFarms[InfectedFarms['Status']==1]['Y coordinate'], 'o', label = 'Infected')
plt.legend(loc = 'upper right')
plt.xlabel('X coordinate ')
plt.ylabel('Y coordinate')
plt.title('Map of the initial farms infected')
# Out:
# Text(0.5,1,'Map of the initial farms infected')

# %%
start_time = time.time()
IP = InfectedFarms['Status']
T = 0
while sum(IP == 1) + sum(IP == 2) > 0:
    T = T+1
#     print("Day", T, "Exposed", sum(IP == 1), "Infected", sum(IP == 2), "Culled", sum(IP == 3))
    
    beta = np.zeros(N)
    for j in range(N):
        beta[j] = beta1[j]*(np.sum((zeta*(cattle[IP == 2]**chi) + sheep[IP == 2]**chi)*K[IP == 2, j]))  
    
    prob_inf = 1 - np.exp(-beta)
    unif = np.random.uniform(0, 1, N)
    for i in range(0,N):
        if (unif[i] <= prob_inf[i] and IP[i] == 0):
            InfectedFarms.loc[i,['Status', 'Time of Exposure']] =[1,T]
    
    InfectedFarms.loc[InfectedFarms['Time of Exposure']+InfectedFarms['Latent Period'] == T, 'Status'] =2

    InfectedFarms.loc[InfectedFarms['Time of Exposure']+
                      InfectedFarms['Latent Period'] + InfectedFarms['Infectious Period']==T, 'Status'] =3

    
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Day 1 Exposed 4 Infected 0 Culled 0
# Day 2 Exposed 4 Infected 0 Culled 0
# Day 3 Exposed 4 Infected 0 Culled 0
# Day 4 Exposed 4 Infected 0 Culled 0
# Day 5 Exposed 3 Infected 1 Culled 0
# Day 6 Exposed 1 Infected 3 Culled 0
# Day 7 Exposed 1 Infected 3 Culled 0
# Day 8 Exposed 1 Infected 3 Culled 0
# 3445
# Day 9 Exposed 1 Infected 4 Culled 0
# Day 10 Exposed 0 Infected 5 Culled 0
# Day 11 Exposed 0 Infected 5 Culled 0
# 3249
# 3452
# Day 12 Exposed 2 Infected 5 Culled 0
# Day 13 Exposed 2 Infected 5 Culled 0
# Day 14 Exposed 2 Infected 4 Culled 1
# Day 15 Exposed 2 Infected 4 Culled 1
# 3262
# Day 16 Exposed 3 Infected 4 Culled 1
# Day 17 Exposed 1 Infected 5 Culled 2
# Day 18 Exposed 1 Infected 4 Culled 3
# Day 19 Exposed 0 Infected 4 Culled 4
# 3369
# Day 20 Exposed 1 Infected 4 Culled 4
# 3246
# Day 21 Exposed 2 Infected 3 Culled 5
# Day 22 Exposed 2 Infected 3 Culled 5
# Day 23 Exposed 2 Infected 2 Culled 6
# Day 24 Exposed 1 Infected 3 Culled 6
# Day 25 Exposed 1 Infected 3 Culled 6
# Day 26 Exposed 1 Infected 3 Culled 6
# Day 27 Exposed 1 Infected 2 Culled 7
# Day 28 Exposed 1 Infected 2 Culled 7
# Day 29 Exposed 0 Infected 3 Culled 7
# 3215
# 3941
# Day 30 Exposed 2 Infected 2 Culled 8
# 3248
# Day 31 Exposed 3 Infected 1 Culled 9
# Day 32 Exposed 3 Infected 1 Culled 9
# Day 33 Exposed 3 Infected 1 Culled 9
# 3372
# 3427
# Day 34 Exposed 3 Infected 3 Culled 9
# Day 35 Exposed 2 Infected 4 Culled 9
# Day 36 Exposed 2 Infected 4 Culled 9
# Day 37 Exposed 2 Infected 4 Culled 9
# Day 38 Exposed 2 Infected 4 Culled 9
# Day 39 Exposed 1 Infected 5 Culled 9
# Day 40 Exposed 0 Infected 6 Culled 9
# Day 41 Exposed 0 Infected 5 Culled 10
# Day 42 Exposed 0 Infected 5 Culled 10
# 3402
# 3446
# Day 43 Exposed 2 Infected 3 Culled 12
# Day 44 Exposed 2 Infected 3 Culled 12
# 3212
# Day 45 Exposed 3 Infected 3 Culled 12
# Day 46 Exposed 3 Infected 0 Culled 15
# Day 47 Exposed 2 Infected 1 Culled 15
# Day 48 Exposed 1 Infected 2 Culled 15
# Day 49 Exposed 0 Infected 3 Culled 15
# Day 50 Exposed 0 Infected 3 Culled 15
# Day 51 Exposed 0 Infected 3 Culled 15
# 3244
# Day 52 Exposed 1 Infected 3 Culled 15
# Day 53 Exposed 1 Infected 3 Culled 15
# Day 54 Exposed 1 Infected 3 Culled 15
# 3436
# Day 55 Exposed 2 Infected 3 Culled 15
# Day 56 Exposed 2 Infected 3 Culled 15
# Day 57 Exposed 1 Infected 4 Culled 15
# Day 58 Exposed 1 Infected 3 Culled 16
# Day 59 Exposed 1 Infected 2 Culled 17
# Day 60 Exposed 1 Infected 1 Culled 18
# Day 61 Exposed 1 Infected 1 Culled 18
# Day 62 Exposed 1 Infected 1 Culled 18
# Day 63 Exposed 0 Infected 2 Culled 18
# Day 64 Exposed 0 Infected 2 Culled 18
# 3259
# Day 65 Exposed 1 Infected 2 Culled 18
# Day 66 Exposed 1 Infected 2 Culled 18
# Day 67 Exposed 0 Infected 3 Culled 18
# Day 68 Exposed 0 Infected 3 Culled 18
# 3035
# Day 69 Exposed 1 Infected 2 Culled 19
# 3243
# Day 70 Exposed 2 Infected 2 Culled 19
# Day 71 Exposed 2 Infected 2 Culled 19
# Day 72 Exposed 2 Infected 2 Culled 19
# Day 73 Exposed 0 Infected 4 Culled 19
# Day 74 Exposed 0 Infected 4 Culled 19
# 3113
# Day 75 Exposed 1 Infected 4 Culled 19
# Day 76 Exposed 1 Infected 3 Culled 20
# Day 77 Exposed 1 Infected 2 Culled 21
# Day 78 Exposed 1 Infected 2 Culled 21
# 3093
# Day 79 Exposed 2 Infected 2 Culled 21
# 3223
# Day 80 Exposed 3 Infected 2 Culled 21
# Day 81 Exposed 3 Infected 2 Culled 21
# 3202
# Day 82 Exposed 4 Infected 1 Culled 22
# Day 83 Exposed 3 Infected 2 Culled 22
# Day 84 Exposed 1 Infected 4 Culled 22
# Day 85 Exposed 0 Infected 5 Culled 22
# Day 86 Exposed 0 Infected 4 Culled 23
# 3024
# Day 87 Exposed 1 Infected 4 Culled 23
# 3121
# Day 88 Exposed 2 Infected 4 Culled 23
# 3138
# Day 89 Exposed 3 Infected 4 Culled 23
# Day 90 Exposed 3 Infected 3 Culled 24
# Day 91 Exposed 2 Infected 4 Culled 24
# Day 92 Exposed 2 Infected 4 Culled 24
# Day 93 Exposed 0 Infected 6 Culled 24
# 3078
# Day 94 Exposed 1 Infected 5 Culled 25
# 3080
# Day 95 Exposed 2 Infected 5 Culled 25
# Day 96 Exposed 2 Infected 4 Culled 26
# Day 97 Exposed 1 Infected 5 Culled 26
# 3209
# Day 98 Exposed 1 Infected 4 Culled 28
# 3104
# Day 99 Exposed 2 Infected 4 Culled 28
# Day 100 Exposed 2 Infected 3 Culled 29
# 3261
# 3284
# Day 101 Exposed 4 Infected 3 Culled 29
# 3374
# Day 102 Exposed 5 Infected 3 Culled 29
# Day 103 Exposed 3 Infected 5 Culled 29
# 3286
# Day 104 Exposed 4 Infected 4 Culled 30
# Day 105 Exposed 3 Infected 5 Culled 30
# Day 106 Exposed 2 Infected 5 Culled 31
# Day 107 Exposed 2 Infected 5 Culled 31
# 3415
# Day 108 Exposed 2 Infected 6 Culled 31
# Day 109 Exposed 2 Infected 6 Culled 31
# 3205
# Day 110 Exposed 3 Infected 4 Culled 33
# Day 111 Exposed 2 Infected 5 Culled 33
# Day 112 Exposed 2 Infected 4 Culled 34
# Day 113 Exposed 2 Infected 4 Culled 34
# Day 114 Exposed 0 Infected 6 Culled 34
# 3184
# 3265
# Day 115 Exposed 2 Infected 5 Culled 35
# 3160
# Day 116 Exposed 3 Infected 4 Culled 36
# Day 117 Exposed 3 Infected 4 Culled 36
# Day 118 Exposed 3 Infected 3 Culled 37
# Day 119 Exposed 3 Infected 3 Culled 37
# Day 120 Exposed 3 Infected 1 Culled 39
# Day 121 Exposed 1 Infected 3 Culled 39
# Day 122 Exposed 1 Infected 3 Culled 39
# Day 123 Exposed 0 Infected 3 Culled 40
# 3048
# Day 124 Exposed 1 Infected 3 Culled 40
# 3183
# Day 125 Exposed 2 Infected 3 Culled 40
# 3038
# Day 126 Exposed 2 Infected 4 Culled 40
# 4020
# Day 127 Exposed 3 Infected 4 Culled 40
# 3348
# Day 128 Exposed 3 Infected 4 Culled 41
# Day 129 Exposed 3 Infected 4 Culled 41
# Day 130 Exposed 3 Infected 4 Culled 41
# 3108
# Day 131 Exposed 4 Infected 4 Culled 41
# 3895
# Day 132 Exposed 4 Infected 5 Culled 41
# 3058
# Day 133 Exposed 4 Infected 5 Culled 42
# Day 134 Exposed 3 Infected 5 Culled 43
# Day 135 Exposed 3 Infected 4 Culled 44
# Day 136 Exposed 2 Infected 5 Culled 44
# Day 137 Exposed 0 Infected 7 Culled 44
# 3299
# 4123
# Day 138 Exposed 2 Infected 7 Culled 44
# Day 139 Exposed 2 Infected 6 Culled 45
# 3107
# Day 140 Exposed 3 Infected 6 Culled 45
# Day 141 Exposed 2 Infected 6 Culled 46
# Day 142 Exposed 2 Infected 5 Culled 47
# Day 143 Exposed 2 Infected 5 Culled 47
# Day 144 Exposed 0 Infected 6 Culled 48
# 3217
# Day 145 Exposed 1 Infected 5 Culled 49
# Day 146 Exposed 0 Infected 5 Culled 50
# Day 147 Exposed 0 Infected 4 Culled 51
# 3105
# Day 148 Exposed 1 Infected 4 Culled 51
# Day 149 Exposed 1 Infected 4 Culled 51
# Day 150 Exposed 1 Infected 1 Culled 54
# 3269
# Day 151 Exposed 2 Infected 1 Culled 54
# Day 152 Exposed 2 Infected 1 Culled 54
# Day 153 Exposed 2 Infected 1 Culled 54
# Day 154 Exposed 1 Infected 2 Culled 54
# 3353
# Day 155 Exposed 1 Infected 3 Culled 54
# Day 156 Exposed 1 Infected 3 Culled 54
# Day 157 Exposed 1 Infected 3 Culled 54
# Day 158 Exposed 1 Infected 3 Culled 54
# Day 159 Exposed 0 Infected 3 Culled 55
# 3277
# Day 160 Exposed 1 Infected 2 Culled 56
# Day 161 Exposed 1 Infected 2 Culled 56
# Day 162 Exposed 1 Infected 1 Culled 57
# Day 163 Exposed 0 Infected 2 Culled 57
# Day 164 Exposed 0 Infected 2 Culled 57
# Day 165 Exposed 0 Infected 2 Culled 57
# Day 166 Exposed 0 Infected 2 Culled 57
# 3130
# Day 167 Exposed 1 Infected 1 Culled 58
# Day 168 Exposed 1 Infected 1 Culled 58
# Day 169 Exposed 1 Infected 1 Culled 58
# Day 170 Exposed 1 Infected 1 Culled 58
# 3173
# Day 171 Exposed 2 Infected 1 Culled 58
# Day 172 Exposed 2 Infected 1 Culled 58
# Day 173 Exposed 2 Infected 1 Culled 58
# Day 174 Exposed 1 Infected 1 Culled 59
# 3191
# Day 175 Exposed 1 Infected 2 Culled 59
# Day 176 Exposed 1 Infected 2 Culled 59
# Day 177 Exposed 0 Infected 3 Culled 59
# Day 178 Exposed 0 Infected 3 Culled 59
# Day 179 Exposed 0 Infected 2 Culled 60
# Day 180 Exposed 0 Infected 2 Culled 60
# Day 181 Exposed 0 Infected 1 Culled 61
# 3606
# Day 182 Exposed 1 Infected 1 Culled 61
# 3236
# Day 183 Exposed 2 Infected 0 Culled 62
# Day 184 Exposed 2 Infected 0 Culled 62
# Day 185 Exposed 2 Infected 0 Culled 62
# Day 186 Exposed 2 Infected 0 Culled 62
# Day 187 Exposed 2 Infected 0 Culled 62
# Day 188 Exposed 2 Infected 0 Culled 62
# Day 189 Exposed 0 Infected 2 Culled 62
# 3302
# Day 190 Exposed 1 Infected 2 Culled 62
# 3151
# Day 191 Exposed 2 Infected 2 Culled 62
# Day 192 Exposed 2 Infected 2 Culled 62
# Day 193 Exposed 0 Infected 4 Culled 62
# Day 194 Exposed 0 Infected 4 Culled 62
# Day 195 Exposed 0 Infected 3 Culled 63
# 3137
# 3298
# Day 196 Exposed 2 Infected 3 Culled 63
# 3150
# Day 197 Exposed 3 Infected 2 Culled 64
# Day 198 Exposed 3 Infected 2 Culled 64
# 3082
# Day 199 Exposed 3 Infected 3 Culled 64
# Day 200 Exposed 3 Infected 3 Culled 64
# 3176
# Day 201 Exposed 4 Infected 3 Culled 64
# Day 202 Exposed 3 Infected 2 Culled 66
# Day 203 Exposed 1 Infected 3 Culled 67
# Day 204 Exposed 1 Infected 3 Culled 67
# Day 205 Exposed 1 Infected 3 Culled 67
# 3159
# Day 206 Exposed 2 Infected 3 Culled 67
# Day 207 Exposed 2 Infected 3 Culled 67
# Day 208 Exposed 1 Infected 4 Culled 67
# Day 209 Exposed 1 Infected 3 Culled 68
# Day 210 Exposed 1 Infected 3 Culled 68
# Day 211 Exposed 1 Infected 2 Culled 69
# Day 212 Exposed 1 Infected 2 Culled 69
# Day 213 Exposed 1 Infected 2 Culled 69
# Day 214 Exposed 1 Infected 2 Culled 69
# 3342
# Day 215 Exposed 2 Infected 1 Culled 70
# Day 216 Exposed 1 Infected 2 Culled 70
# Day 217 Exposed 1 Infected 2 Culled 70
# Day 218 Exposed 1 Infected 2 Culled 70
# Day 219 Exposed 1 Infected 2 Culled 70
# Day 220 Exposed 0 Infected 3 Culled 70
# Day 221 Exposed 0 Infected 2 Culled 71
# 3276
# Day 222 Exposed 1 Infected 2 Culled 71
# Day 223 Exposed 1 Infected 2 Culled 71
# Day 224 Exposed 1 Infected 2 Culled 71
# Day 225 Exposed 0 Infected 3 Culled 71
# Day 226 Exposed 0 Infected 2 Culled 72
# Day 227 Exposed 0 Infected 2 Culled 72
# Day 228 Exposed 0 Infected 2 Culled 72
# Day 229 Exposed 0 Infected 1 Culled 73
# Day 230 Exposed 0 Infected 1 Culled 73
# --- 347.3204565048218 seconds ---

# %% [markdown]
# # InP
# This is a dataframe of just the farms that were infected. I add in aditional columns so I know the time exposed, infected and culled

# %%
InP = InfectedFarms[InfectedFarms['Time of Exposure']!=-100]
InP['Time of Infection'] = InP['Time of Exposure'] + InP['Latent Period']
InP['Time of Culling'] = InP['Time of Infection'] + InP['Infectious Period']
# Out:
# /home/emma/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/emma/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Animation
# If you would like the animation to be faster, increase fps

# %%
exposed = []
infect = []
culled = []

#appends each day (so that the classes can be colour coordinated)
for i in range(max(InP['Time of Culling'])+1):
    exposed.append(InP[InP['Time of Exposure'] <= i])
    infect.append(InP[InP['Time of Infection']<=i])
    culled.append(InP[InP['Time of Culling']<=i])

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
# All suscpetible farms initally
ax = plt.axes(xlim=(min(xcoord), max(xcoord)), 
              ylim=(min(ycoord), max(ycoord)))
ax.plot(xcoord, ycoord, 'o', alpha=.01, ms=10, label = 'Suscpetible farms')
line1, = ax.plot([], [], 'o', color = 'b', alpha = 0.3, label = 'Exposed farms')
line2,  = ax.plot([], [], 'o', color = 'r', alpha = 0.3, label = 'Infected farms')
line3,  = ax.plot([], [], 'o', color = 'k', alpha = 1, label = 'Culled farms')
time_text = ax.text(0.7, 0.9, '', transform=ax.transAxes)

# initialization function: plot the background of each frame
def init():
    line1.set_data([], [])
    line2.set_data([],[])
    line3.set_data([],[])
    time_text.set_text('')
    return line1, line2, line3,

# animation function of dataframes' list
def animate(i):
    line1.set_data(exposed[i]['X coordinate'], exposed[i]['Y coordinate'])
    line2.set_data(infect[i]['X coordinate'], infect[i]['Y coordinate'])
    line3.set_data(culled[i]['X coordinate'], culled[i]['Y coordinate'])
    time_text.set_text('Timestep {}'.format(i+1))
    return line1, line2, line3, time_text

# call the animator, frames*(1/fps) is the speed of the animation.
# set number of frames to the length of your list of dataframes
anim = animation.FuncAnimation(fig, animate, frames=len(culled), init_func=init, interval=20, blit=True)
plt.legend(loc = 'lower right')
plt.title('Cumbria')
plt.xlabel('X coordinate (m)')
plt.ylabel('Y coordiante (m)')
anim.save('FMD.mp4', fps=1.5)

# %%
num_infect = []
for k in infect:
    num_infect.append(len(k))
num_culled = []
for j in culled:
    num_culled.append(len(j))
num_exposed = []
for z in exposed:
    num_exposed.append(len(z))

# %%
B = [a_i - b_i for a_i, b_i in zip(num_infect, num_culled)]
Z = [a_i - b_i for a_i, b_i in zip(num_exposed, num_infect)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1da55f574887> in <module>()
# ----> 1 B = [a_i - b_i for a_i, b_i in zip(num_infect, num_culled)]
#       2 Z = [a_i - b_i for a_i, b_i in zip(num_exposed, num_infect)]
#
# NameError: name 'num_infect' is not defined

# %%
plt.figure(figsize = (20,10))
plt.plot(range(len(culled)), B, label = 'Number of infectious premises')
plt.plot(range(len(culled)), Z, label = 'Number of exposed farms')
plt.plot(range(len(culled)), num_culled, label = 'Number of culled farms')
plt.legend(loc = 'upper left')
plt.xlabel('Time, days')
plt.ylabel('percentage of farms')
# Out:
# Text(0,0.5,'percentage of farms')
