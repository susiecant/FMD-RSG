# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
endemic_level = np.load('endemicinf.npy')

# %%
np.mean(endemic_level, axis =0 ) # THIS IS WHAT YOU PUT IN THE TABLE
# Out:
# array([234.10583333])

# %%
infection = np.load('Infect.npy')
# np.mean(infection, axis = 0)[0]

# %%
plt.plot(range(800), np.mean(infection, axis = 0)[0]) # TIME VS MEAN NUMBER OF INFECTION PLOTS
